# %%
# Cell 1: Setup directories and define asset map
import os
import re
from pathlib import Path
import urllib.request

# Target directories
BASE_DIR = Path(r"C:\Users\Rob\Documents\github\simone")
ASSETS_DIR = BASE_DIR / "assets" / "images"
ASSETS_DIR.mkdir(parents=True, exist_ok=True)

# Clean, mapped dictionary of key assets found in the design
ASSET_MAP = {
    "woman_spring_portrait.png": "https://media-public.canva.com/xrbrg/MAGV0Exrbrg/1/wm_s.png",
    "woman_spring_thumb.png": "https://media-public.canva.com/xrbrg/MAGV0Exrbrg/1/t.png",
    "ladybug_cutout.png": "https://media-public.canva.com/dmrrE/MAFEMYdmrrE/1/t.png",
    "tree_four_seasons.png": "https://media-public.canva.com/shqa4/MAGOyFshqa4/1/t.png",
    "adult_crafting.png": "https://media-public.canva.com/G7DY0/MAFuMHG7DY0/1/t.png",
    "prom_balloons.png": "https://media-public.canva.com/uKrMI/MAE48zuKrMI/1/t.png",
    "festive_box_balloons.gif": "https://video-public.canva.com/VAGmj4ngkDk/v/awgl7ldqxv.gif",
    "hands_unity_sticker.gif": "https://video-public.canva.com/VAFAiPykEWI/v/d835d8021b.gif",
    "branding_large_photo.jpg": (
        "https://media.canva.com/v2/image-resize/format:JPG/height:800/quality:92/"
        "uri:ifs%3A%2F%2FM%2F6735ce56-5c2f-4060-8738-67e2d63af89c/watermark:F/width:800"
        "?csig=AAAAAAAAAAAAAAAAAAAAAD0PsaG0obOfH8ya5G0BHAqV3LpguLnRTRboF4OMfG7w"
        "&exp=1789657482&osig=AAAAAAAAAAAAAAAAAAAAAHk9TCW0pQR9_TsvQFCwKGODgd_kgOdsfdeDSynrl5de"
        "&signer=media-rpc&x-canva-quality=screen"
    ),
    "branding_thumb.jpg": (
        "https://media.canva.com/v2/image-resize/format:JPG/height:150/quality:75/"
        "uri:ifs%3A%2F%2FM%2F6735ce56-5c2f-4060-8738-67e2d63af89c/watermark:F/width:150"
        "?csig=AAAAAAAAAAAAAAAAAAAAAGqnd6a3huAVjlVEFn3Wq1XJexE3_1Tq6ZOyj1JaAaxH"
        "&exp=1789657482&osig=AAAAAAAAAAAAAAAAAAAAAIyXl3DBqUeEBo8Mjmi8cvmbP4M5Olhc3Z5Pwe779hIZ"
        "&signer=media-rpc&x-canva-quality=micro_thumbnail"
    )
}

print(f"Target folder configured: {ASSETS_DIR}")
# Out:
# Target folder configured: C:\Users\Rob\Documents\github\simone\assets\images

# %%
# Cell 2: Download assets to local folder
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"
}

for filename, url in ASSET_MAP.items():
    output_path = ASSETS_DIR / filename
    try:
        req = urllib.request.Request(url, headers=headers)
        with urllib.request.urlopen(req) as response, open(output_path, "wb") as out_file:
            out_file.write(response.read())
        print(f"✓ Downloaded: {filename}")
    except Exception as e:
        print(f"✗ Failed {filename}: {e}")

print("\nAsset download complete!")
# Out:
# ✓ Downloaded: woman_spring_portrait.png
# ✓ Downloaded: woman_spring_thumb.png
# ✓ Downloaded: ladybug_cutout.png
# ✓ Downloaded: tree_four_seasons.png
# ✓ Downloaded: adult_crafting.png
# ✓ Downloaded: prom_balloons.png
# ✓ Downloaded: festive_box_balloons.gif
# ✓ Downloaded: hands_unity_sticker.gif
# ✓ Downloaded: branding_large_photo.jpg
# ✓ Downloaded: branding_thumb.jpg
#
# Asset download complete!

# %%
# generate_pages.py
# Run this script to generate all subpages inside C:\Users\Rob\Documents\github\simone

import os
from pathlib import Path

TARGET_DIR = Path(r"C:\Users\Rob\Documents\github\simone")
TARGET_DIR.mkdir(parents=True, exist_ok=True)

SHARED_CSS = """
    :root {
      --bg-cream: #fdf3dd;
      --card-blue: #d6e8f7;
      --card-lilac: #caaacd;
      --card-gold: #cb962e;
      --card-orange: #ef601e;
      --text-dark: #373d3b;
      --text-black: #111111;
      --radius-lg: 24px;
      --radius-md: 16px;
    }

    * {
      box-sizing: border-box;
      margin: 0;
      padding: 0;
    }

    body {
      font-family: 'Plus Jakarta Sans', system-ui, -apple-system, sans-serif;
      background-color: var(--bg-cream);
      color: var(--text-dark);
      line-height: 1.6;
    }

    /* Top Navigation */
    .site-nav {
      max-width: 1200px;
      margin: 0 auto;
      padding: 24px 20px;
      display: flex;
      justify-content: space-between;
      align-items: center;
      flex-wrap: wrap;
      gap: 16px;
    }

    .brand-logo {
      font-size: 1.35rem;
      font-weight: 800;
      letter-spacing: 0.25em;
      text-transform: uppercase;
      color: var(--text-dark);
      text-decoration: none;
    }

    .nav-links {
      display: flex;
      gap: 12px;
      list-style: none;
      flex-wrap: wrap;
    }

    .nav-links a {
      text-decoration: none;
      font-size: 0.9rem;
      font-weight: 600;
      color: var(--text-dark);
      padding: 8px 14px;
      border-radius: 999px;
      transition: all 0.2s ease;
    }

    .nav-links a:hover,
    .nav-links a.active {
      background-color: rgba(55, 61, 59, 0.08);
    }

    /* Page Container */
    .page-wrap {
      max-width: 1100px;
      margin: 0 auto;
      padding: 32px 20px 80px;
      display: flex;
      flex-direction: column;
      gap: 48px;
    }

    /* Hero Section */
    .hero-panel {
      border-radius: var(--radius-lg);
      padding: 48px;
      position: relative;
      display: grid;
      grid-template-columns: 1fr 340px;
      align-items: center;
      gap: 32px;
      overflow: hidden;
      box-shadow: 0 10px 30px rgba(0, 0, 0, 0.05);
    }

    .hero-copy h1 {
      font-size: 2.5rem;
      line-height: 1.2;
      font-weight: 800;
      margin-bottom: 16px;
    }

    .hero-copy p {
      font-size: 1.15rem;
      max-width: 580px;
      margin-bottom: 24px;
    }

    .hero-img-wrap {
      display: flex;
      justify-content: center;
      align-items: center;
    }

    .hero-img-wrap img {
      max-height: 280px;
      max-width: 100%;
      object-fit: contain;
    }

    .btn-action {
      display: inline-block;
      background: var(--text-dark);
      color: #fff;
      padding: 12px 28px;
      border-radius: 999px;
      font-weight: 700;
      text-decoration: none;
      transition: transform 0.2s ease;
    }

    .btn-action:hover {
      transform: translateY(-2px);
    }

    /* Content Blocks */
    .content-grid {
      display: grid;
      grid-template-columns: repeat(auto-fit, minmax(300px, 1fr));
      gap: 24px;
    }

    .info-card {
      background: #ffffff;
      border-radius: var(--radius-md);
      padding: 32px;
      box-shadow: 0 4px 16px rgba(0, 0, 0, 0.04);
      display: flex;
      flex-direction: column;
      gap: 12px;
    }

    .info-card h3 {
      font-size: 1.3rem;
      font-weight: 700;
    }

    /* Footer */
    footer {
      border-top: 1px solid rgba(55, 61, 59, 0.15);
      padding: 40px 20px;
      text-align: center;
      color: #666;
      font-size: 0.9rem;
    }

    footer a {
      color: var(--text-dark);
      font-weight: 600;
      text-decoration: none;
      margin: 0 8px;
    }

    @media (max-width: 768px) {
      .hero-panel {
        grid-template-columns: 1fr;
        padding: 32px 24px;
      }
      .hero-copy h1 {
        font-size: 2rem;
      }
    }
"""

SUBPAGES = {
    "subscription.html": {
        "title": "Yearly Craft Subscription | Frankie & Hunter",
        "theme_bg": "var(--card-lilac)",
        "h1": "A Full Year of Family Craft Traditions",
        "desc": "Four curated, seasonal boxes delivered right to your door. Designed to bring children, parents, and grandparents together around the table with all the materials, adhesives, and keepsake projects you need.",
        "img": "assets/images/ladybug_cutout.png",
        "cards": [
            ("Spring & Easter Awakenings", "Paper-cut flora, botanical stamping, and hand-painted wooden egg sets ready for springtime tables."),
            ("Summer Sunshine & Storytelling", "Pressed-flower suncatchers, handmade windchimes, and outdoor clay keepsakes for vacation afternoons."),
            ("Autumn Harvest & Warmth", "Festive paper lanterns, fabric leaf garlands, and cosy crafting sessions as the evenings draw in."),
            ("Winter Holiday Heirlooms", "Handcrafted tree ornaments, bespoke gifting wrap, and personalised keepsakes built to last generations.")
        ]
    },
    "build-a-box.html": {
        "title": "Build Your Own Craft Box | Frankie & Hunter",
        "theme_bg": "var(--card-gold)",
        "h1": "Craft Exactly What Sparks Your Joy",
        "desc": "Pick and choose the materials, project cards, and finishing touches. Whether tailoring a surprise package for a grandchild or curating supplies for your own weekend project, build a bundle tailored to you.",
        "img": "assets/images/prom_balloons.png",
        "cards": [
            ("Step 1: Pick Your Base Project", "Select from decoupage trays, hand-bound memory scrapbooks, ceramic painting, or collage kits."),
            ("Step 2: Curate Materials & Paints", "Choose your colour story: soft pastels, vibrant gouache, earthy ceramics, or glitter and ribbons."),
            ("Step 3: Tools & Adhesives Included", "We supply child-safe scissors, craft PVA, precision brushes, and cotton aprons."),
            ("Step 4: Personal Gift Dedication", "Add a handwritten postcard with your personal message for the recipient.")
        ]
    },
    "mystery-box.html": {
        "title": "Mystery Craft Box | Frankie & Hunter",
        "theme_bg": "var(--card-orange)",
        "h1": "The Joy of an Unboxing Surprise",
        "desc": "A surprise parcel of exclusive materials, mystery patterns, and limited-run tools. Unseal the box, put on the kettle, and discover a brand-new medium you have not tried before.",
        "img": "assets/images/festive_box_balloons.gif",
        "cards": [
            ("Mystery Technique of the Month", "Each edition features a secret technique—from paper marbling to needle felting and botanical casting."),
            ("Full-Size Secret Supplies", "No sample sizes: you get full tubes, specialty papers, and keepsake tools carefully wrapped in tissue."),
            ("Step-by-Step Illustrated Booklet", "Clear, friendly guides written for beginners through to seasoned tabletop makers."),
            ("Exclusive Maker Community Badge", "Share your unboxing and finished piece with fellow crafters using #FrankieAndHunter.")
        ]
    },
    "seasonal.html": {
        "title": "Seasonal Celebrations | Frankie & Hunter",
        "theme_bg": "linear-gradient(135deg, #5de0e6 0%, #004aad 100%)",
        "text_color": "#ffffff",
        "h1": "Celebrate Solstices, Holidays & Harvests",
        "desc": "Marking the passage of the year through handmade decor. Replace store-bought plastic with soulful table settings, wreaths, and festive garlands made by hand.",
        "img": "assets/images/tree_four_seasons.png",
        "cards": [
            ("Spring Blossom Garlands", "Delicate crepe paper flowers and hand-strung wooden bead garlands for your mantle."),
            ("Midsummer Table Settings", "Block-printed linen napkins, hand-painted place cards, and citrus-pressed coasters."),
            ("Autumn Equinox Wreaths", "Woven willow rings, dried seedheads, and dyed raffia for your front door."),
            ("Yuletide Lanterns & Bells", "Perforated brass-paper luminarias and cast beeswax decorations that warm the winter table.")
        ]
    },
    "sip-and-craft.html": {
        "title": "Sip & Craft Nights | Frankie & Hunter",
        "theme_bg": "linear-gradient(135deg, #ff3131 0%, #ff914d 100%)",
        "text_color": "#ffffff",
        "h1": "Unwind, Pour a Drink & Get Creative",
        "desc": "A relaxed alternative to screen time. Designed for adults, friends, and couples to enjoy creative headspace, laughter, and tactile crafting alongside a favourite beverage.",
        "img": "assets/images/adult_crafting.png",
        "cards": [
            ("Grown-Up Projects", "Sophisticated terrazzo trinket dishes, botanical block printing, and custom soy candle pouring."),
            ("Zero Experience Needed", "Stress-free kits with foolproof materials so you can chat and sip while creating freely."),
            ("Curated Drink Pairings", "Includes mocktail and wine pairing suggestion cards tailored to the mood of the craft."),
            ("Host Your Own Evening", "Bulk kits available to host 4 to 12 friends in the comfort of your living room.")
        ]
    },
    "events.html": {
        "title": "Events, Gatherings & Parties | Frankie & Hunter",
        "theme_bg": "linear-gradient(135deg, #ff66c4 0%, #ffde59 100%)",
        "text_color": "#111111",
        "h1": "Crafting for Memorable Gatherings",
        "desc": "From Granny's weekend sleepovers and milestone birthdays to baby showers and bridal parties—shared creative tables build bonds and leave everyone with a keepsake to treasure.",
        "img": "assets/images/hands_unity_sticker.gif",
        "cards": [
            ("Granny's Sleepover Bundles", "Quick-drying, low-mess crafts created specifically for grandparents and grandchildren to finish together."),
            ("Birthday Celebration Packs", "Individual craft boxes that double as the party activity and the go-home favor bag."),
            ("Baby & Bridal Showers", "Collaborative projects like guestbook quilt squares, keepsake advice cards, and floral crowns."),
            ("Custom Event Kits", "Tell us your guest count, color scheme, and venue—we will pack bespoke kits ready to lay on the tables.")
        ]
    }
}

TEMPLATE = """<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>{title}</title>
  <link rel="preconnect" href="https://fonts.googleapis.com">
  <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
  <link href="https://fonts.googleapis.com/css2?family=Plus+Jakarta+Sans:wght@400;600;700;800&display=swap" rel="stylesheet">
  <style>
{css}
  </style>
</head>
<body>

  <header class="site-nav">
    <a href="index.html" class="brand-logo">Frankie &amp; Hunter</a>
    <nav>
      <ul class="nav-links">
        <li><a href="index.html">Home</a></li>
        <li><a href="subscription.html" {sub_active}>Subscription</a></li>
        <li><a href="build-a-box.html" {box_active}>Build a Box</a></li>
        <li><a href="mystery-box.html" {mys_active}>Mystery Box</a></li>
        <li><a href="seasonal.html" {sea_active}>Seasonal</a></li>
        <li><a href="sip-and-craft.html" {sip_active}>Sip &amp; Craft</a></li>
        <li><a href="events.html" {eve_active}>Events</a></li>
      </ul>
    </nav>
  </header>

  <main class="page-wrap">
    
    <section class="hero-panel" style="background: {theme_bg}; color: {text_color};">
      <div class="hero-copy">
        <h1>{h1}</h1>
        <p>{desc}</p>
        <a href="mailto:hello@frankieandhunter.co.uk?subject=Inquiry" class="btn-action">Enquire Now</a>
      </div>
      <div class="hero-img-wrap">
        <img src="{img}" alt="{h1}">
      </div>
    </section>

    <section class="content-grid">
      {cards_html}
    </section>

  </main>

  <footer>
    <p>&copy; 2026 Frankie &amp; Hunter. Handcrafted memories and creative sanctuaries.</p>
    <p style="margin-top: 8px;">
      <a href="index.html">Home</a> | 
      <a href="subscription.html">Subscriptions</a> | 
      <a href="build-a-box.html">Custom Boxes</a> | 
      <a href="mystery-box.html">Mystery</a> | 
      <a href="seasonal.html">Seasonal</a> | 
      <a href="sip-and-craft.html">Sip &amp; Craft</a> | 
      <a href="events.html">Events</a>
    </p>
  </footer>

</body>
</html>
"""

for filename, data in SUBPAGES.items():
    cards_markup = ""
    for title, desc in data["cards"]:
        cards_markup += f"""
      <div class="info-card">
        <h3>{title}</h3>
        <p>{desc}</p>
      </div>"""

    rendered = TEMPLATE.format(
        title=data["title"],
        css=SHARED_CSS,
        sub_active='class="active"' if filename == "subscription.html" else "",
        box_active='class="active"' if filename == "build-a-box.html" else "",
        mys_active='class="active"' if filename == "mystery-box.html" else "",
        sea_active='class="active"' if filename == "seasonal.html" else "",
        sip_active='class="active"' if filename == "sip-and-craft.html" else "",
        eve_active='class="active"' if filename == "events.html" else "",
        theme_bg=data["theme_bg"],
        text_color=data.get("text_color", "var(--text-black)"),
        h1=data["h1"],
        desc=data["desc"],
        img=data["img"],
        cards_html=cards_markup
    )

    out_file = TARGET_DIR / filename
    with open(out_file, "w", encoding="utf-8") as f:
        f.write(rendered)
    print(f"✓ Generated: {out_file}")

print("\nAll subpages successfully created!")
# Out:
# ✓ Generated: C:\Users\Rob\Documents\github\simone\subscription.html
# ✓ Generated: C:\Users\Rob\Documents\github\simone\build-a-box.html
# ✓ Generated: C:\Users\Rob\Documents\github\simone\mystery-box.html
# ✓ Generated: C:\Users\Rob\Documents\github\simone\seasonal.html
# ✓ Generated: C:\Users\Rob\Documents\github\simone\sip-and-craft.html
# ✓ Generated: C:\Users\Rob\Documents\github\simone\events.html
#
# All subpages successfully created!

# %%
from pathlib import Path
from playwright.async_api import async_playwright

# Project paths
BASE_DIR = Path(r"C:\Users\Rob\Documents\github\simone")
OUTPUT_DIR = BASE_DIR / "exports"
PNG_DIR = OUTPUT_DIR / "png"
PDF_DIR = OUTPUT_DIR / "pdf"

PNG_DIR.mkdir(parents=True, exist_ok=True)
PDF_DIR.mkdir(parents=True, exist_ok=True)

async def render_pages():
    html_files = sorted(list(BASE_DIR.glob("*.html")))

    if not html_files:
        print(f"No HTML files found in {BASE_DIR}")
        return

    print(f"Found {len(html_files)} HTML files to export.\n")

    async with async_playwright() as p:
        # Launch headless browser
        browser = await p.chromium.launch()
        context = await browser.new_context(
            viewport={"width": 1440, "height": 900},
            device_scale_factor=2
        )
        page = await context.new_page()

        for html_file in html_files:
            stem = html_file.stem
            file_url = html_file.resolve().as_uri()

            print(f"Rendering: {html_file.name}...")

            # Load local HTML and wait for network/fonts to resolve
            await page.goto(file_url, wait_until="networkidle")
            await page.evaluate("document.fonts.ready")

            # 1. Export Full-Page PNG
            png_output = PNG_DIR / f"{stem}.png"
            await page.screenshot(
                path=str(png_output),
                full_page=True
            )
            print(f"  ✓ PNG: {png_output.name}")

            # 2. Export Screen-Accurate PDF
            await page.emulate_media(media="screen")
            pdf_output = PDF_DIR / f"{stem}.pdf"
            await page.pdf(
                path=str(pdf_output),
                print_background=True,
                format="A4",
                margin={"top": "20px", "bottom": "20px", "left": "20px", "right": "20px"}
            )
            print(f"  ✓ PDF: {pdf_output.name}\n")

        await browser.close()

    print("All exports completed successfully!")
    print(f"PNG files saved to: {PNG_DIR}")
    print(f"PDF files saved to: {PDF_DIR}")

# Execute directly in the notebook cell
await render_pages()
# Out:
# Found 7 HTML files to export.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[7], line 67
#      64     print(f"PDF files saved to: {PDF_DIR}")
#      66 # Execute directly in the notebook cell
# ---> 67 await render_pages()
#
# Cell In[7], line 22, in render_pages()
#      18     return
#      20 print(f"Found {len(html_files)} HTML files to export.\n")
# ---> 22 async with async_playwright() as p:
#      23     # Launch headless browser
#      24     browser = await p.chromium.launch()
#      25     context = await browser.new_context(
#      26         viewport={"width": 1440, "height": 900},
#      27         device_scale_factor=2
#      28     )
#
# File ~\anaconda3\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ...

# %%
# !pip install playwright
# Out:
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    -------- ------------------------------- 8.4/38.6 MB 45.0 MB/s eta 0:00:01
#    -------------------- ------------------- 19.7/38.6 MB 49.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.3/38.6 MB 56.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 54.8 MB/s eta 0:00:00
# ...
#
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    -------------------- ------------------- 1/2 [playwright]
#    ---------------------------------------- 2/2 [playwright]
#
# ...

# %%
import sys
import asyncio
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor
from playwright.sync_api import sync_playwright

# Project paths
BASE_DIR = Path(r"C:\Users\Rob\Documents\github\simone")
OUTPUT_DIR = BASE_DIR / "exports"
PNG_DIR = OUTPUT_DIR / "png"
PDF_DIR = OUTPUT_DIR / "pdf"

PNG_DIR.mkdir(parents=True, exist_ok=True)
PDF_DIR.mkdir(parents=True, exist_ok=True)

def _render_worker():
    # Enforce Windows Proactor loop on the worker thread for subprocess support
    if sys.platform == "win32":
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

    html_files = sorted(list(BASE_DIR.glob("*.html")))

    if not html_files:
        print(f"No HTML files found in {BASE_DIR}")
        return

    print(f"Found {len(html_files)} HTML files to export.\n")

    with sync_playwright() as p:
        browser = p.chromium.launch()
        context = browser.new_context(
            viewport={"width": 1440, "height": 900},
            device_scale_factor=2
        )
        page = context.new_page()

        for html_file in html_files:
            stem = html_file.stem
            file_url = html_file.resolve().as_uri()

            print(f"Rendering: {html_file.name}...")

            # Load local HTML and wait for network/fonts to resolve
            page.goto(file_url, wait_until="networkidle")
            page.evaluate("document.fonts.ready")

            # 1. Export Full-Page PNG
            png_output = PNG_DIR / f"{stem}.png"
            page.screenshot(
                path=str(png_output),
                full_page=True
            )
            print(f"  ✓ PNG: {png_output.name}")

            # 2. Export Screen-Accurate PDF
            page.emulate_media(media="screen")
            pdf_output = PDF_DIR / f"{stem}.pdf"
            page.pdf(
                path=str(pdf_output),
                print_background=True,
                format="A4",
                margin={"top": "20px", "bottom": "20px", "left": "20px", "right": "20px"}
            )
            print(f"  ✓ PDF: {pdf_output.name}\n")

        browser.close()

    print("All exports completed successfully!")
    print(f"PNG files saved to: {PNG_DIR}")
    print(f"PDF files saved to: {PDF_DIR}")

# Execute via ThreadPoolExecutor to bypass Jupyter's active main-thread loop
with ThreadPoolExecutor(max_workers=1) as executor:
    future = executor.submit(_render_worker)
    future.result()
# Out:
# Found 7 HTML files to export.
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[8], line 75
#      73 with ThreadPoolExecutor(max_workers=1) as executor:
#      74     future = executor.submit(_render_worker)
# ---> 75     future.result()
#
# File ~\anaconda3\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\anaconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# ...

# %%
import sys
import subprocess

# Downloads the required Chromium headless binary to your AppData folder
subprocess.run([sys.executable, "-m", "playwright", "install", "chromium"], check=True)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[9], line 5
#       2 import subprocess
#       4 # Downloads the required Chromium headless binary to your AppData folder
# ----> 5 subprocess.run([sys.executable, "-m", "playwright", "install", "chromium"], check=True)
#
# File ~\anaconda3\Lib\subprocess.py:577, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     575     retcode = process.poll()
#     576     if check and retcode:
# --> 577         raise CalledProcessError(retcode, process.args,
#     578                                  output=stdout, stderr=stderr)
#     579 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['C:\\Users\\Rob\\anaconda3\\python.exe', '-m', 'playwright', 'install', 'chromium']' returned non-zero exit status 1.

# %%
import sys
import asyncio
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor
from playwright.sync_api import sync_playwright

# Project paths
BASE_DIR = Path(r"C:\Users\Rob\Documents\github\simone")
OUTPUT_DIR = BASE_DIR / "exports"
PNG_DIR = OUTPUT_DIR / "png"
PDF_DIR = OUTPUT_DIR / "pdf"

PNG_DIR.mkdir(parents=True, exist_ok=True)
PDF_DIR.mkdir(parents=True, exist_ok=True)

def _render_worker():
    if sys.platform == "win32":
        asyncio.set_event_loop_policy(asyncio.WindowsProactorEventLoopPolicy())

    html_files = sorted(list(BASE_DIR.glob("*.html")))

    if not html_files:
        print(f"No HTML files found in {BASE_DIR}")
        return

    print(f"Found {len(html_files)} HTML files to export.\n")

    with sync_playwright() as p:
        # Launch locally installed Edge or Chrome instead of downloading Playwright Chromium
        browser = None
        for channel_name in ["msedge", "chrome"]:
            try:
                browser = p.chromium.launch(channel=channel_name)
                print(f"Using local system browser: {channel_name}\n")
                break
            except Exception:
                continue

        if not browser:
            print("Error: Neither Microsoft Edge nor Google Chrome could be located on your system.")
            return

        context = browser.new_context(
            viewport={"width": 1440, "height": 900},
            device_scale_factor=2
        )
        page = context.new_page()

        for html_file in html_files:
            stem = html_file.stem
            file_url = html_file.resolve().as_uri()

            print(f"Rendering: {html_file.name}...")

            # Load local HTML and wait for fonts and assets to finish rendering
            page.goto(file_url, wait_until="networkidle")
            page.evaluate("document.fonts.ready")

            # 1. Export Full-Page PNG
            png_output = PNG_DIR / f"{stem}.png"
            page.screenshot(
                path=str(png_output),
                full_page=True
            )
            print(f"  ✓ PNG: {png_output.name}")

            # 2. Export Screen-Accurate PDF
            page.emulate_media(media="screen")
            pdf_output = PDF_DIR / f"{stem}.pdf"
            page.pdf(
                path=str(pdf_output),
                print_background=True,
                format="A4",
                margin={"top": "20px", "bottom": "20px", "left": "20px", "right": "20px"}
            )
            print(f"  ✓ PDF: {pdf_output.name}\n")

        browser.close()

    print("All exports completed successfully!")
    print(f"PNG files saved to: {PNG_DIR}")
    print(f"PDF files saved to: {PDF_DIR}")

# Run within thread pool to prevent Jupyter asyncio conflicts
with ThreadPoolExecutor(max_workers=1) as executor:
    future = executor.submit(_render_worker)
    future.result()
# Out:
# Found 7 HTML files to export.
#
# Using local system browser: msedge
#
# Rendering: build-a-box.html...
#   ✓ PNG: build-a-box.png
#   ✓ PDF: build-a-box.pdf
#
# Rendering: events.html...
#   ✓ PNG: events.png
#   ✓ PDF: events.pdf
#
# Rendering: index.html...
#   ✓ PNG: main.png
#   ✓ PDF: main.pdf
#
# Rendering: mystery-box.html...
#   ✓ PNG: mystery-box.png
#   ✓ PDF: mystery-box.pdf
#
# Rendering: seasonal.html...
#   ✓ PNG: seasonal.png
#   ✓ PDF: seasonal.pdf
#
# Rendering: sip-and-craft.html...
#   ✓ PNG: sip-and-craft.png
#   ✓ PDF: sip-and-craft.pdf
#
# Rendering: subscription.html...
#   ✓ PNG: subscription.png
#   ✓ PDF: subscription.pdf
#
# All exports completed successfully!
# PNG files saved to: C:\Users\Rob\Documents\github\simone\exports\png
# PDF files saved to: C:\Users\Rob\Documents\github\simone\exports\pdf
